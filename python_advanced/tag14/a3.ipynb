# %%
import cv2
import numpy as np
import pickle
import matplotlib.pyplot as plt
from pathlib import Path
import os
from sklearn.utils import shuffle

# %%
folder = Path().resolve() / "PetImages"

# %%
# img_paths = [cv2.imread(str(imgpath), cv2.IMREAD_GRAYSCALE) for category in ["Cat", "Dog"] for imgpath in (folder /category).iterdir()]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-44b094358e45> in <module>
# ----> 1 img_paths = [cv2.imread(str(imgpath), cv2.IMREAD_GRAYSCALE) for category in ["Cat", "Dog"] for imgpath in (folder /category).iterdir()[:4]]
#
# <ipython-input-17-44b094358e45> in <listcomp>(.0)
# ----> 1 img_paths = [cv2.imread(str(imgpath), cv2.IMREAD_GRAYSCALE) for category in ["Cat", "Dog"] for imgpath in (folder /category).iterdir()[:4]]
#
# TypeError: 'generator' object is not subscriptable

# %%
for category in ["Cat", "Dog"]:
    path = folder / category
    for img_path in path.iterdir():
        img_array = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)

        plt.imshow(img_array, cmap="gray")
        plt.show()

        img_array = cv2.resize(img_array, (100, 100))
        plt.imshow(img_array, cmap="gray")
        plt.show()
        break

# %%
def create_dataset(DATADIR="PetImages", CATEGORIES=["Cat", "Dog"], IMG_SIZE=100):
    features = []
    target = []
    errors = []

    for label, category in enumerate(CATEGORIES):
        folder = Path().resolve() / DATADIR
        path = folder / category
        for img_path in path.iterdir():
            try:
                img_array = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
                img_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))

                features.append(img_array)
                target.append(label)
            except Exception as e:
                errors.append(img_path)
                print(e)
    return shuffle(np.array(features), np.array(target))

# %%
feat, targ = create_dataset()
# Out:
# OpenCV(4.3.0) C:\projects\opencv-python\opencv\modules\imgproc\src\resize.cpp:3929: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# OpenCV(4.3.0) C:\projects\opencv-python\opencv\modules\imgproc\src\resize.cpp:3929: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# OpenCV(4.3.0) C:\projects\opencv-python\opencv\modules\imgproc\src\resize.cpp:3929: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# OpenCV(4.3.0) C:\projects\opencv-python\opencv\modules\imgproc\src\resize.cpp:3929: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# OpenCV(4.3.0) C:\projects\opencv-python\opencv\modules\imgproc\src\resize.cpp:3929: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# OpenCV(4.3.0) C:\projects\opencv-python\opencv\modules\imgproc\src\resize.cpp:3929: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# ...

# %%
targ.shape
# Out:
# (24946,)
